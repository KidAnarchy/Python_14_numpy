# %% [markdown]
# ## Math

# %%
# Library Math
import math

# %%
x = 45
print(math.sin(x))
# Out:
# 0.8509035245341184

# %%
a = 5
print(math.pi)
print(math.sqrt(a))
print(math.factorial(a))
# Out:
# 3.141592653589793
# 2.23606797749979
# 120

# %%
# Circle area
r = float(input('Input radian:'))
area = math.pi*r**2
print('Area ',area)
# Out:
# Input radian:2.54
# Area  20.268299163899908

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

a = float(input())
b = float(input())
c = float(input())

CR = c*math.pi/180
area = 1/2*a*b*math.sin(CR)

print('area = ',area,' sq.cm')
# Out:
# 10
# 10
# 90
# area =  50.0  sq.cm
